# %%
import base64 
from io import BytesIO
from PIL import Image

input_url = "Test_Image/Image1.png"
input_mask = "Test_Mask/Mask1.png"

# Get image 
image = Image.open(input_url)
mask = Image.open(input_mask)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
def pil2bas64(image): 
    im_file = BytesIO()
    image.save(im_file, format="JPEG")
    im_bytes = im_file.getvalue()  # im_bytes: image in binary format.
    im_b64 = base64.b64encode(im_bytes)
    return im_b64

# %%
im_b64 = pil2bas64(image)

# %%
mask_b64 = pil2bas64(mask)

# %%
print(mask_b64)
# Out:
# b'...'

# %%
def bs642pil(im_b64): 
    im_bytes = base64.b64decode(im_b64)   # im_bytes is a binary image
    im_file = BytesIO(im_bytes)  # convert image to file-like object
    img = Image.open(im_file)   # img is now PIL Image object
    return img

# %%
image = bs642pil(im_b64)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
mask = bs642pil(mask_b64)
mask
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
